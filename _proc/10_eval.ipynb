# %% [raw]
# ---
# description: API details
# output-file: eval.html
# title: Eval
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| include: false
from nbdev.showdoc import *

# %%
#| echo: false
#| output: asis
show_doc(generate_plot_data)
# Out:
# /home/mila/g/guillaume.huguet/.conda/envs/mioflow/lib/python3.10/site-packages/fastcore/docscrape.py:225: UserWarning: Unknown section Arguments:
#   else: warn(msg)
# ---
#
# ### generate_plot_data
#
# >      generate_plot_data (model, df, n_points, n_trajectories, n_bins,
# >                          sample_with_replacement=False, use_cuda=False,
# >                          samples_key='samples', logger=None, autoencoder=None,
# >                          recon=False)

# %%
#| echo: false
#| output: asis
show_doc(generate_trajectories)
# Out:
# ---
#
# ### generate_trajectories
#
# >      generate_trajectories (model, df, n_trajectories=30, n_bins=100,
# >                             sample_with_replacement=False, use_cuda=False,
# >                             samples_key='samples', autoencoder=None,
# >                             recon=False)

# %%
#| echo: false
#| output: asis
show_doc(generate_points)
# Out:
# ---
#
# ### generate_points
#
# >      generate_points (model, df, n_points=100, sample_with_replacement=False,
# >                       use_cuda=False, samples_key='samples', sample_time=None,
# >                       autoencoder=None, recon=False)

# %%
#| echo: false
#| output: asis
show_doc(calculate_nn)
# Out:
# ---
#
# ### calculate_nn
#
# >      calculate_nn (df:pandas.core.frame.DataFrame,
# >                    generated:Union[numpy.ndarray,list]=None,
# >                    trajectories:Union[numpy.ndarray,list]=None,
# >                    compare_to:Union[Literal['time'],Literal['any']]='time', ho
# >                    w:Union[Literal['start'],Literal['middle'],Literal['end']]=
# >                    'start', k:int=1, groups:Union[numpy.ndarray,list]=None,
# >                    sample_key:str='samples', method:str='mean',
# >                    logger:logging.Logger=None)
#
# Arguments:
#     df (pd.DataFrame): DataFrame containing all points and time sample specified by `sample_key`
#     generated (np.ndarray | list): A list of the generate points with shape
#         `(n_groups, n_points, n_dims)`, where `n_groups` is the total number of time indicies
#         as specified in `groups`.
#     trajectories (np.ndarray | list): A list with three dimensions that correspond to:
# ...

# %%
#| echo: false
#| output: asis
show_doc(get_points_from_trajectories)
# Out:
# ---
#
# ### get_points_from_trajectories
#
# >      get_points_from_trajectories (n_groups:int,
# >                                    trajectories:Union[numpy.ndarray,list], how
# >                                    :Union[Literal['start'],Literal['middle'],L
# >                                    iteral['end']]='start',
# >                                    logger:logging.Logger=None)
#
# Arguments:
#     n_groups (int): how many time points there are total.
#     trajectories (np.ndarray | list): A list with three dimensions that correspond to:
#         `(n_bins, n_points, n_dims)`, where `n_points` are the number of points / trajectories there are,
#         `n_bins` correponds to how the trajectories were smoothed via binning (e.g. if there were 5 total
#         time points one might have 100 bins to draw a smoother line when plotting), and `n_dims` are the
#         number of dimensions the points are in (e.g. 2).
# ...

# %%
#| echo: false
#| output: asis
show_doc(get_cell_indexes)
# Out:
# /home/mila/g/guillaume.huguet/.conda/envs/mioflow/lib/python3.10/site-packages/fastcore/docscrape.py:225: UserWarning: potentially wrong underline length...
# Notes:
# ----------- in
# Notes:
# -----------...
#   else: warn(msg)
# /home/mila/g/guillaume.huguet/.conda/envs/mioflow/lib/python3.10/site-packages/fastcore/docscrape.py:225: UserWarning: potentially wrong underline length...
# Arguments:
# ----------- in
# Notes:
# -----------...
#   else: warn(msg)
# /home/mila/g/guillaume.huguet/.conda/envs/mioflow/lib/python3.10/site-packages/fastcore/docscrape.py:225: UserWarning: potentially wrong underline length...
# Returns:
# ----------- in
# Notes:
# -----------...
#   else: warn(msg)
# /home/mila/g/guillaume.huguet/.conda/envs/mioflow/lib/python3.10/site-packages/fastcore/docscrape.py:225: UserWarning: Unknown section Notes:
#   else: warn(msg)
# ...

# %%
#| echo: false
#| output: asis
show_doc(generate_tjnet_trajectories)
# Out:
# /home/mila/g/guillaume.huguet/.conda/envs/mioflow/lib/python3.10/site-packages/fastcore/docscrape.py:225: UserWarning: potentially wrong underline length...
# Arguments:
# ----------- in
# Arguments:
# -----------...
#   else: warn(msg)
# /home/mila/g/guillaume.huguet/.conda/envs/mioflow/lib/python3.10/site-packages/fastcore/docscrape.py:225: UserWarning: potentially wrong underline length...
# Returns:
# ----------- in
# Arguments:
# -----------...
#   else: warn(msg)
# ---
#
# ### generate_tjnet_trajectories
#
# >      generate_tjnet_trajectories (model, df, n_bins=10, use_cuda=False,
# >                                   samples_key='samples', autoencoder=None,
# >                                   recon=False, where='end', start=0)
