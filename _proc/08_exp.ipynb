# %% [raw]
# ---
# description: Functions to define the experiemnt setup, logger, and save the parameters.
# output-file: exp.html
# title: Experiment
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#|output: asis
#| echo: false
show_doc(test_exp)
# Out:
# ---
#
# ### test_exp
#
# >      test_exp ()

# %%
#|output: asis
#| echo: false
show_doc(find_exps)
# Out:
# /home/solstice/anaconda3/envs/ml/lib/python3.9/site-packages/fastcore/docscrape.py:225: UserWarning: Unknown section Arguments:
#   else: warn(msg)
# ---
#
# ### find_exps
#
# >      find_exps (path, params)

# %%
#|output: asis
#| echo: false
show_doc(is_config_subset)
# Out:
# ---
#
# ### is_config_subset
#
# >      is_config_subset (truth, params)

# %%
#|output: asis
#| echo: false
show_doc(setup_exp)
# Out:
# ---
#
# ### setup_exp
#
# >      setup_exp (path, params, name=None)

# %%
#|output: asis
#| echo: false
show_doc(save_exp_params)
# Out:
# ---
#
# ### save_exp_params
#
# >      save_exp_params (path, params, logger=None)

# %%
#|output: asis
#| echo: false
show_doc(load_exp_params)
# Out:
# ---
#
# ### load_exp_params
#
# >      load_exp_params (path)

# %%
#|output: asis
#| echo: false
show_doc(gen_exp_name)
# Out:
# /home/solstice/anaconda3/envs/ml/lib/python3.9/site-packages/fastcore/docscrape.py:225: UserWarning: potentially wrong underline length...
# Returns:
# ---------- in
# Returns:
# ----------...
#   else: warn(msg)
# /home/solstice/anaconda3/envs/ml/lib/python3.9/site-packages/fastcore/docscrape.py:225: UserWarning: Unknown section Returns:
#   else: warn(msg)
# ---
#
# ### gen_exp_name
#
# >      gen_exp_name (name=None)

# %%
#|output: asis
#| echo: false
show_doc(list_exps)
# Out:
# /home/solstice/anaconda3/envs/ml/lib/python3.9/site-packages/fastcore/docscrape.py:225: UserWarning: potentially wrong underline length...
# Notes:
# ---------- in
# Notes:
# ----------...
#   else: warn(msg)
# /home/solstice/anaconda3/envs/ml/lib/python3.9/site-packages/fastcore/docscrape.py:225: UserWarning: Unknown section Notes:
#   else: warn(msg)
# ---
#
# ### list_exps
#
# >      list_exps (path)

# %%
#|output: asis
#| echo: false
show_doc(exp_param_filename)
# Out:
# ---
#
# ### exp_param_filename
#
# >      exp_param_filename (path)

# %%
#|output: asis
#| echo: false
show_doc(exp_log_filename)
# Out:
# ---
#
# ### exp_log_filename
#
# >      exp_log_filename (path)

# %%
#|output: asis
#| echo: false
show_doc(config_exp_logger)
# Out:
# ---
#
# ### config_exp_logger
#
# >      config_exp_logger (path)
