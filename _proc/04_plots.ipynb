# %% [raw]
# ---
# description: API details
# output-file: plots.html
# title: Plots
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| include: false
from nbdev.showdoc import *

# %%
#|output: asis
#| echo: false
show_doc(plot_losses)
# Out:
# ---
#
# ### plot_losses
#
# >      plot_losses (local_losses=None, batch_losses=None, globe_losses=None,
# >                   save=False, path='/home/guillaumehuguet/MIOFlow/imgs',
# >                   file='losses.png')

# %%
#|output: asis
#| echo: false
show_doc(plot_comparision)
# Out:
# ---
#
# ### plot_comparision
#
# >      plot_comparision (df, generated, trajectories, palette='viridis',
# >                        df_time_key='samples', save=False,
# >                        path='/home/guillaumehuguet/MIOFlow/imgs',
# >                        file='comparision.png', x='d1', y='d2', z='d3',
# >                        is_3d=False)

# %%
#|output: asis
#| echo: false
show_doc(new_plot_comparisions)
# Out:
# ---
#
# ### new_plot_comparisions
#
# >      new_plot_comparisions (df, generated, trajectories, palette='viridis',
# >                             df_time_key='samples', x='d1', y='d2', z='d3',
# >                             groups=None, save=False,
# >                             path='/home/guillaumehuguet/MIOFlow/imgs',
# >                             file='comparision.png', is_3d=False)

# %%
#|output: asis
#| echo: false
show_doc(plot_gene_trends)
# Out:
# /home/guillaumehuguet/anaconda3/envs/mioflow2/lib/python3.8/site-packages/fastcore/docscrape.py:225: UserWarning: potentially wrong underline length...
# Returns:
# ---------- in
# Notes:
#     - first four arguments `genes`, `top_idxs`, `inverse`, and `colors` are output from `get_cell_indexes`...
#   else: warn(msg)
# /home/guillaumehuguet/anaconda3/envs/mioflow2/lib/python3.8/site-packages/fastcore/docscrape.py:225: UserWarning: Unknown section Arguments:
#   else: warn(msg)
# /home/guillaumehuguet/anaconda3/envs/mioflow2/lib/python3.8/site-packages/fastcore/docscrape.py:225: UserWarning: Unknown section Returns:
#   else: warn(msg)
# ---
#
# ### plot_gene_trends
#
# >      plot_gene_trends (genes, top_idxs, inverse, colors, samples=None,
# >                        groups=None, n_cols=None, n_rows=None, where='end',
# >                        start=0, top_n=None, cell_types=None,
# >                        use_cell_types=True, save:bool=False,
# >                        path:str='/home/guillaumehuguet/MIOFlow/imgs',
# >                        file:str='gene_trends.png')
#
# Notes:
#     - first four arguments `genes`, `top_idxs`, `inverse`, and `colors` are output from `get_cell_indexes`
#         see that function's docstring for more information.
