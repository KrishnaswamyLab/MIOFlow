# %% [raw]
# ---
# description: API details
# output-file: utils.html
# title: Utils
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| include: false
from nbdev.showdoc import *

# %%
#| echo: false
#| output: asis
show_doc(config_criterion)
# Out:
# ---
#
# ### config_criterion
#
# >      config_criterion (criterion_name:str='ot')

# %%
#| echo: false
#| output: asis
show_doc(config_hold_out)
# Out:
# ---
#
# ### config_hold_out
#
# >      config_hold_out (df:pandas.core.frame.DataFrame, hold_out:str='random',
# >                       hold_one_out:bool=False)

# %%
#| echo: false
#| output: asis
show_doc(set_seeds)
# Out:
# ---
#
# ### set_seeds
#
# >      set_seeds (seed:int)

# %%
#| echo: false
#| output: asis
show_doc(generate_steps)
# Out:
# ---
#
# ### generate_steps
#
# >      generate_steps (groups)

# %%
#| echo: false
#| output: asis
show_doc(to_np)
# Out:
# ---
#
# ### to_np
#
# >      to_np (data)

# %%
#| echo: false
#| output: asis
show_doc(sample)
# Out:
# ---
#
# ### sample
#
# >      sample (data, group, size=(100,), replace=False, to_torch=False,
# >              use_cuda=False)

# %%
#| echo: false
#| output: asis
show_doc(group_extract)
# Out:
# ---
#
# ### group_extract
#
# >      group_extract (df, group, index='samples', groupby='samples')

# %%
#| echo: false
#| output: asis
show_doc(get_times_from_groups)
# Out:
# ---
#
# ### get_times_from_groups
#
# >      get_times_from_groups (groups, where='start', start=0)

# %%
#| echo: false
#| output: asis
show_doc(get_sample_n_from_df)
# Out:
# /home/mila/g/guillaume.huguet/.conda/envs/mioflow/lib/python3.10/site-packages/fastcore/docscrape.py:225: UserWarning: potentially wrong underline length...
# Returns:
# --------- in
# Arguments:
# ----------...
#   else: warn(msg)
# ---
#
# ### get_sample_n_from_df
#
# >      get_sample_n_from_df (df, n, samples_key='samples', samples=None,
# >                            groups=None, drop_index=False)

# %%
#| echo: false
#| output: asis
show_doc(get_cell_types_from_df)
# Out:
# ---
#
# ### get_cell_types_from_df
#
# >      get_cell_types_from_df (df, cell_type_key=None, cell_types=None)

# %%
#| echo: false
#| output: asis
show_doc(get_groups_from_df)
# Out:
# ---
#
# ### get_groups_from_df
#
# >      get_groups_from_df (df, samples_key='samples', samples=None)
